# %% [markdown]
# # Proyek Analisis Data: E-Commerce public
# - Kelompok : **Matplotlib**
# - Anggota : </br>
# 10122280 - Daffa Revaldy Ichsan</br>

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - **Pertanyaan 1 (10122292 - Wildan Mujjahid R)** <br>
#   `Identifikasi 5 kategori produk dengan penjualan tertinggi dan 5 kategori produk dengan penjualan terendah. Selanjutnya, jelaskan bagaimana tren penjualan untuk 5 kategori teratas produk tersebut dalam beberapa tahun terakhir, apakah menunjukkan peningkatan, penurunan, atau stabil dalam jumlah penjualan?`
# - **Pertanyaan 2 (10122293 - Imat Imansyah)** <br>
#   `Grafik pertumbuhan penjualan (%), kapan mengalami kenaikan dan penurunan`
# - **Pertanyaan 3 (10122294 - Putri Aprilia)** <br>
#   `Berapa perbandingan jumlah pesanan yang dikirim tepat waktu dan pesanan yang dikirim tidak tepat waktu pada tahun 2018?`
# - **Pertanyaan 4 (10122304 - Hilman Fauzi M)** <br>
#   `Kota dengan Rating tertinggi dan terendah berdasarkan jumlah penjualan atau ulasan`
# - **Pertanyaan 5 (10122305 - Dicky Bariyadi S)** <br>
#   `Top 5 customer terbanyak dan berasal dari kota mana?`

# %% [markdown]
# ## Menyiapkan semua library yang dibutuhkan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
missing_value_format = ['N.A', 'na', 'n.a.','n/a','?','-']

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# **CUSTOMERS DATASET**

# %%
#Customers Dataset
customers_dataset_df = pd.read_csv("/customers_dataset.csv", na_values = missing_value_format)
customers_dataset_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# **GEOLOCATION DATASET**

# %%
#Geolocation Dataset
geolocation_dataset_df = pd.read_csv("/geolocation_dataset.csv", na_values = missing_value_format)
geolocation_dataset_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# **ORDER ITEMS DATASET**

# %%
#Order Items Dataset
order_items_dataset_df = pd.read_csv("/order_items_dataset.csv", na_values = missing_value_format)
order_items_dataset_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %% [markdown]
# **ORDER PAYMENTS DATASET**

# %%
#Order Payments Dataset
order_payments_dataset_df = pd.read_csv("/order_payments_dataset.csv", na_values = missing_value_format)
order_payments_dataset_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# **ORDER REVIEWS DATASET**

# %%
#Order Reviews Dataset
order_reviews_dataset_df = pd.read_csv("/order_reviews_dataset.csv", na_values = missing_value_format)
order_reviews_dataset_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %% [markdown]
# **ORDERS DATASET**

# %%
#Orders Dataset
orders_dataset_df = pd.read_csv("/orders_dataset.csv", na_values = missing_value_format)
orders_dataset_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %% [markdown]
# **PRODUCT CATEGORY NAME TRANSLATION**

# %%
#Product Category Name Translation
product_category_name_translation_df = pd.read_csv("/product_category_name_translation.csv", na_values = missing_value_format)
product_category_name_translation_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# **PRODUCTS DATASET**

# %%
#Products Dataset
products_dataset_df = pd.read_csv("/products_dataset.csv", na_values = missing_value_format)
products_dataset_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %% [markdown]
# **SELLERS DATASET**

# %%
#Sellers Dataset
sellers_dataset_df = pd.read_csv("/sellers_dataset.csv", na_values = missing_value_format)
sellers_dataset_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### `ORDERS DATASET`

# %%
orders_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders_dataset_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
print("Jumlah Duplikasi :",orders_dataset_df.duplicated().sum())
# Out:
# Jumlah Duplikasi : 0

# %%
orders_dataset_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# top             2018-05-09 15:48:00           2018-05-08 23:38:46
# freq                             47                             3
#
#        order_estimated_delivery_date
# count                          99441
# unique                           459
# top              2017-12-20 00:00:00
# freq                             522

# %% [markdown]
# #### `CUSTOMERS DATASET`

# %%
#Cek Missing Values
customers_dataset_df.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
print("Jumlah duplikasi: ", customers_dataset_df.duplicated().sum())
customers_dataset_df.describe()
# Out:
# Jumlah duplikasi:  0
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# #### `ORDER REVIEWS DATASET`

# %%
order_reviews_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11566 non-null  object
#  4   review_comment_message   40971 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
print("Jumlah Duplikasi : ",order_reviews_dataset_df.duplicated().sum())
# Out:
# Jumlah Duplikasi :  0

# %%
order_reviews_dataset_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87658
# review_comment_message     58253
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
order_reviews_dataset_df.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# #### `ORDER ITEMS DATASET`

# %%
order_items_dataset_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_items_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
print("Jumlah Duplikasi : ",order_items_dataset_df.duplicated().sum())
# Out:
# Jumlah Duplikasi :  0

# %%
order_items_dataset_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# #### `SELLER DATASET`

# %%
sellers_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
sellers_dataset_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
print("Jumlah Duplikasi :",sellers_dataset_df.duplicated().sum())
# Out:
# Jumlah Duplikasi : 0

# %%
sellers_dataset_df.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# #### `PRODUCT DATASET`

# %%
# Mengecek missing Values
products_dataset_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
# Mengecek Data Duplikat
print('jumlah duplikasi data :',products_dataset_df.duplicated().sum())
# Out:
# jumlah duplikasi data : 0

# %%
products_dataset_df.dtypes
# Out:
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %% [markdown]
# #### `KATEGORI NAME TRANSLATION DATASET`

# %%
product_category_name_translation_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
print('jumlah duplikasi data :',product_category_name_translation_df.duplicated().sum())
# Out:
# jumlah duplikasi data : 0

# %%
product_category_name_translation_df.dtypes
# Out:
# product_category_name            object
# product_category_name_english    object
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Cleaning Table `customers_dataset_df`

# %% [markdown]
# ##### Duplicate data

# %%
print("Jumlah duplikasi: ", customers_dataset_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Missing values

# %%
customers_dataset_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# #### Cleaning Table `order_items_dataset_df`

# %%
order_items_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items_dataset_df['shipping_limit_date'] = pd.to_datetime(order_items_dataset_df['shipping_limit_date'])#, format= '%Y-%m-%d %X')

# %%
order_items_dataset_df.dtypes
# Out:
# order_id                       object
# order_item_id                   int64
# product_id                     object
# seller_id                      object
# shipping_limit_date    datetime64[ns]
# price                         float64
# freight_value                 float64
# dtype: object

# %% [markdown]
# ##### Inaccurate values

# %%
customers_dataset_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# #### Cleaning Table `order_reviews_dataset_df`

# %% [markdown]
# ##### Missing values

# %%
order_reviews_dataset_df[order_reviews_dataset_df.review_comment_message.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 5      15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6      07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# ...                                 ...                               ...
# 99217  c6b270c61f67c9f7cb07d84ea8aeaf8b  48f7ee67313eda32bfcf5b9c1dd9522d
# 99218  af2dc0519de6e0720ef0c74292fb4114  d699c734a0b1c8111f2272a3f36d398c
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
#
#        review_score review_comment_title review_comment_message  \
# 0                 4                  NaN                    NaN
# 1                 5                  NaN                    NaN
# 2                 5                  NaN                    NaN
# 5                 1                  NaN                    NaN
# 6                 5                  NaN                    NaN
# ...             ...                  ...                    ...
# 99217             5                  NaN                    NaN
# 99218             5                  NaN                    NaN
# 99219             5                  NaN                    NaN
# 99220             5                  NaN                    NaN
# 99222             4                  NaN                    NaN
#
#       review_creation_date review_answer_timestamp
# 0      2018-01-18 00:00:00     2018-01-18 21:46:59
# 1      2018-03-10 00:00:00     2018-03-11 03:05:13
# 2      2018-02-17 00:00:00     2018-02-18 14:36:24
# 5      2018-04-13 00:00:00     2018-04-16 00:39:37
# 6      2017-07-16 00:00:00     2017-07-18 19:30:34
# ...                    ...                     ...
# 99217  2017-12-13 00:00:00     2017-12-14 11:09:36
# 99218  2018-04-27 00:00:00     2018-04-30 01:18:57
# 99219  2018-07-07 00:00:00     2018-07-14 17:18:30
# 99220  2017-12-09 00:00:00     2017-12-11 20:06:42
# 99222  2018-07-01 00:00:00     2018-07-02 12:59:13
#
# [58253 rows x 7 columns]

# %%
order_reviews_dataset_df[order_reviews_dataset_df.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# 0                 4                  NaN
# 1                 5                  NaN
# 2                 5                  NaN
# 3                 5                  NaN
# 4                 5                  NaN
# ...             ...                  ...
# 99219             5                  NaN
# 99220             5                  NaN
# 99221             5                  NaN
# 99222             4                  NaN
# 99223             1                  NaN
#
#                                   review_comment_message review_creation_date  \
# 0                                                    NaN  2018-01-18 00:00:00
# 1                                                    NaN  2018-03-10 00:00:00
# 2                                                    NaN  2018-02-17 00:00:00
# 3                  Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4      Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# ...                                                  ...                  ...
# 99219                                                NaN  2018-07-07 00:00:00
# 99220                                                NaN  2017-12-09 00:00:00
# 99221  Excelente mochila, entrega super rápida. Super...  2018-03-22 00:00:00
# 99222                                                NaN  2018-07-01 00:00:00
# 99223  meu produto chegou e ja tenho que devolver, po...  2017-07-03 00:00:00
#
#       review_answer_timestamp
# 0         2018-01-18 21:46:59
# 1         2018-03-11 03:05:13
# 2         2018-02-18 14:36:24
# 3         2017-04-21 22:02:06
# 4         2018-03-02 10:26:53
# ...                       ...
# 99219     2018-07-14 17:18:30
# 99220     2017-12-11 20:06:42
# 99221     2018-03-23 09:10:43
# 99222     2018-07-02 12:59:13
# 99223     2017-07-03 21:01:49
#
# [87658 rows x 7 columns]

# %%
order_reviews_dataset_df.fillna(value='No Comments',inplace = True)
order_reviews_dataset_df
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# 0                 4          No Comments
# 1                 5          No Comments
# 2                 5          No Comments
# 3                 5          No Comments
# 4                 5          No Comments
# ...             ...                  ...
# 99219             5          No Comments
# 99220             5          No Comments
# 99221             5          No Comments
# 99222             4          No Comments
# 99223             1          No Comments
#
#                                   review_comment_message review_creation_date  \
# 0                                            No Comments  2018-01-18 00:00:00
# 1                                            No Comments  2018-03-10 00:00:00
# 2                                            No Comments  2018-02-17 00:00:00
# 3                  Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4      Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# ...                                                  ...                  ...
# 99219                                        No Comments  2018-07-07 00:00:00
# 99220                                        No Comments  2017-12-09 00:00:00
# 99221  Excelente mochila, entrega super rápida. Super...  2018-03-22 00:00:00
# 99222                                        No Comments  2018-07-01 00:00:00
# 99223  meu produto chegou e ja tenho que devolver, po...  2017-07-03 00:00:00
#
#       review_answer_timestamp
# 0         2018-01-18 21:46:59
# 1         2018-03-11 03:05:13
# 2         2018-02-18 14:36:24
# 3         2017-04-21 22:02:06
# 4         2018-03-02 10:26:53
# ...                       ...
# 99219     2018-07-14 17:18:30
# 99220     2017-12-11 20:06:42
# 99221     2018-03-23 09:10:43
# 99222     2018-07-02 12:59:13
# 99223     2017-07-03 21:01:49
#
# [99224 rows x 7 columns]

# %%
order_reviews_dataset_df.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %% [markdown]
# ##### inaccurate type

# %%
order_reviews_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
# DateTimeColumns = ['review_creation_date','review_answer_timestamp'],

# for column in DateTimeColumns:
#     order_reviews_dataset_df[DateTimeColumns] = pd.to_datetime(order_reviews_dataset_df[DateTimeColumns],format = '%Y-%m-%d %X
order_reviews_dataset_df['review_creation_date'] = pd.to_datetime(order_reviews_dataset_df['review_creation_date'],format = '%Y-%m-%d %X')
order_reviews_dataset_df['review_answer_timestamp'] = pd.to_datetime(order_reviews_dataset_df['review_answer_timestamp'],format = '%Y-%m-%d %X')
order_reviews_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %% [markdown]
# #### Cleaning Table `orders_dataset_df`

# %% [markdown]
# ##### Duplicate Data

# %%
print("Jumlah duplikasi: ", orders_dataset_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Missing Values

# %%
orders_dataset_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders_dataset_df["order_approved_at"].fillna(value="No Date or Related Date", inplace=True)
orders_dataset_df["order_delivered_carrier_date"].fillna(value="No Date or Related Date", inplace=True)
orders_dataset_df["order_delivered_customer_date"].fillna(value="No Date or Related Date", inplace=True)

# %%
orders_dataset_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# ##### Inaccurate Values

# %%
orders_dataset_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp        order_approved_at  \
# count         99441                    99441                    99441
# unique            8                    98875                    90734
# top       delivered      2018-04-11 10:48:14  No Date or Related Date
# freq          96478                        3                      160
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         99441                         99441
# unique                        81019                         95665
# top         No Date or Related Date       No Date or Related Date
# freq                           1783                          2965
#
#        order_estimated_delivery_date
# count                          99441
# unique                           459
# top              2017-12-20 00:00:00
# freq                             522

# %% [markdown]
# #### Cleaning Table `seller_city`

# %% [markdown]
# ##### Inaccurate values

# %%
sellers_dataset_df.sort_values('seller_city',inplace=True)
sellers_dataset_df.head(1)
# Out:
#                             seller_id  seller_zip_code_prefix seller_city  \
# 517  ceb7b4fb9401cd378de7886317ad1b47                   22790    04482255
#
#     seller_state
# 517           RJ

# %%
sellers_dataset_df['seller_city']= sellers_dataset_df['seller_city'].replace(to_replace = '04482255', value = 'rio de janeiro')
sellers_dataset_df.head(1)
# Out:
#                             seller_id  seller_zip_code_prefix     seller_city  \
# 517  ceb7b4fb9401cd378de7886317ad1b47                   22790  rio de janeiro
#
#     seller_state
# 517           RJ

# %%
sellers_dataset_df.sort_values('seller_city')
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 2067  c8143b3069f6746a77421b5ce30a450c                   75345
# 2153  2f4b9d112bfa44a214bc6cef085d17c8                   29600
# 2589  3a52d63a8f9daf5a28f3626d7eb9bd28                   71900
# 2115  717b78b0950b51ed00b1471d858b0edc                   18220
# 1812  0aa124728afc1131dff5655f4c6f487b                   37135
# ...                                ...                     ...
# 1678  94e93ce877be27a515118dbfd2c2be41                   15502
# 746   9da1ca0bef29ee170e541927a5aeabdc                   15500
# 2472  abbf6046bbdf1028606a5bc7f00c99e7                   89820
# 2730  ca5832c6960267b71041f74bb39e8b12                   89820
# 2352  76de363de16dacc923eec8daf91df504                   89825
#
#           seller_city seller_state
# 2067  abadia de goias           GO
# 2153   afonso claudio           ES
# 2589  aguas claras df           SP
# 2115         alambari           SP
# 1812          alfenas           MG
# ...               ...          ...
# 1678      votuporanga           SP
# 746       votuporanga           SP
# 2472          xanxere           SC
# 2730          xanxere           SC
# 2352            xaxim           SC
#
# [3095 rows x 4 columns]

# %% [markdown]
# #### Cleaning Table `products_dataset_df`

# %% [markdown]
# **Handling missing Values**

# %%
products_dataset_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
# menangani missing values dengan method ffill (mengisi nilai yang hilang dengan nilai dari baris sebelumnya)

products_dataset_df['product_weight_g'].fillna(method='ffill', inplace=True)
products_dataset_df['product_length_cm'].fillna(method='ffill', inplace=True)
products_dataset_df['product_height_cm'].fillna(method='ffill', inplace=True)
products_dataset_df['product_width_cm'].fillna(method='ffill', inplace=True)
products_dataset_df['product_name_lenght'].fillna(method='ffill', inplace=True)
products_dataset_df['product_description_lenght'].fillna(method='ffill', inplace=True)
products_dataset_df['product_photos_qty'].fillna(method='ffill', inplace=True)

# %%
# manangani missing Values dengan modus

mode_category = products_dataset_df['product_category_name'].mode()[0]
products_dataset_df['product_category_name'].fillna(value=mode_category, inplace=True)

# %%
products_dataset_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# #### Explore tabel `df_produk`, `df_order_items` & `df_kategori`

# %% [markdown]
# **Merge `df_produk` & `df_order_item`**

# %%
kategori_info = pd.merge(products_dataset_df[['product_id', 'product_category_name']],order_items_dataset_df[['order_item_id','product_id','shipping_limit_date']], on='product_id', how='inner')

# %%
kategori_info
# Out:
#                               product_id   product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5              perfumaria
# 1       3aa071139cb16b67ca9e5dea641aaa2f                   artes
# 2       96bd76ec8810374ed1b65e291975717f           esporte_lazer
# 3       cef67bcfe19066a932b7673e239eb23d                   bebes
# 4       9dc1a7de274444849c219cff195d0b71   utilidades_domesticas
# ...                                  ...                     ...
# 112645  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112646  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112647  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112648  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112649  106392145fca363410d287a815be6de4         cama_mesa_banho
#
#         order_item_id shipping_limit_date
# 0                   1 2018-04-30 17:33:54
# 1                   1 2018-02-06 19:11:15
# 2                   1 2018-07-11 21:30:20
# 3                   1 2018-08-07 09:10:13
# 4                   1 2018-04-17 01:30:23
# ...               ...                 ...
# 112645              2 2018-01-10 03:32:09
# 112646              1 2018-03-14 02:30:48
# 112647              2 2018-03-14 02:30:48
# 112648              3 2018-03-14 02:30:48
# 112649              1 2018-07-02 08:30:34
#
# [112650 rows x 4 columns]

# %% [markdown]
# **Merge `kategori_info` & `df_kategori`**

# %%
kategori_info = pd.merge(kategori_info,product_category_name_translation_df[['product_category_name', 'product_category_name_english']], on='product_category_name', how='inner')

# %%
kategori_info.head()
# Out:
#                          product_id product_category_name  order_item_id  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5            perfumaria              1
# 1  6a2fb4dd53d2cdb88e0432f1284a004c            perfumaria              1
# 2  6a2fb4dd53d2cdb88e0432f1284a004c            perfumaria              1
# 3  0d009643171aee696f4733340bc2fdd0            perfumaria              1
# 4  0d009643171aee696f4733340bc2fdd0            perfumaria              1
#
#   shipping_limit_date product_category_name_english
# 0 2018-04-30 17:33:54                     perfumery
# 1 2017-11-23 21:31:31                     perfumery
# 2 2017-12-14 16:33:14                     perfumery
# 3 2017-08-03 09:50:14                     perfumery
# 4 2018-05-30 10:38:35                     perfumery

# %%
# Menghapus kategori yang bahasa brazil
kategori_info = kategori_info.drop('product_category_name',axis=1)

# Mengubah nama kolom kategori dan order item id
kategori_info = kategori_info.rename(columns={'product_category_name_english': 'product_category'})
kategori_info = kategori_info.rename(columns={'order_item_id': 'jumlah_terjual'})

kategori_info.head()
# Out:
#                          product_id  jumlah_terjual shipping_limit_date  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5               1 2018-04-30 17:33:54
# 1  6a2fb4dd53d2cdb88e0432f1284a004c               1 2017-11-23 21:31:31
# 2  6a2fb4dd53d2cdb88e0432f1284a004c               1 2017-12-14 16:33:14
# 3  0d009643171aee696f4733340bc2fdd0               1 2017-08-03 09:50:14
# 4  0d009643171aee696f4733340bc2fdd0               1 2018-05-30 10:38:35
#
#   product_category
# 0        perfumery
# 1        perfumery
# 2        perfumery
# 3        perfumery
# 4        perfumery

# %% [markdown]
# **Menentukan kategori dengan 5 penjualan teratas dan 5 penjualan terbawah**

# %%
count_kategori = kategori_info['product_category'].value_counts()
count_kategori
# Out:
# bed_bath_table               12718
# health_beauty                 9670
# sports_leisure                8641
# furniture_decor               8334
# computers_accessories         7827
#                              ...
# arts_and_craftmanship           24
# la_cuisine                      14
# cds_dvds_musicals               14
# fashion_childrens_clothes        8
# security_and_services            2
# Name: product_category, Length: 71, dtype: int64

# %%
# Mencari 5 kategori teratas
kategori_head = count_kategori.head(5)
pd.DataFrame(kategori_head)
# Out:
#                        product_category
# bed_bath_table                    12718
# health_beauty                      9670
# sports_leisure                     8641
# furniture_decor                    8334
# computers_accessories              7827

# %%
# Mencari 5 Kategori dengan penjualan paling sedikit
kategori_tail = count_kategori.tail(5)
pd.DataFrame(kategori_tail)
# Out:
#                            product_category
# arts_and_craftmanship                    24
# la_cuisine                               14
# cds_dvds_musicals                        14
# fashion_childrens_clothes                 8
# security_and_services                     2

# %% [markdown]
# **Menentukan trend penjualan kategori terlaris**

# %%
top_five = count_kategori.head(5)
top_five = pd.DataFrame(top_five)
top_five
# Out:
#                        product_category
# bed_bath_table                    12718
# health_beauty                      9670
# sports_leisure                     8641
# furniture_decor                    8334
# computers_accessories              7827

# %%
# Filter data untuk kategori paling banyak terjual

kategori_terlaris_1 = top_five.index[0]
kategori_terlaris_1 = kategori_info[kategori_info['product_category'] == kategori_terlaris_1]

kategori_terlaris_2 = top_five.index[1]
kategori_terlaris_2 = kategori_info[kategori_info['product_category'] == kategori_terlaris_2]

kategori_terlaris_3 = top_five.index[2]
kategori_terlaris_3 = kategori_info[kategori_info['product_category'] == kategori_terlaris_3]

kategori_terlaris_4 = top_five.index[3]
kategori_terlaris_4 = kategori_info[kategori_info['product_category'] == kategori_terlaris_4]

kategori_terlaris_5 = top_five.index[4]
kategori_terlaris_5 = kategori_info[kategori_info['product_category'] == kategori_terlaris_5]

# %%
kategori_terlaris_1
# Out:
#                              product_id  jumlah_terjual shipping_limit_date  \
# 39996  14aa47b7fe5c25522b47b4b29c98dcb9               1 2018-02-09 12:29:52
# 39997  14aa47b7fe5c25522b47b4b29c98dcb9               2 2018-02-09 12:29:52
# 39998  14aa47b7fe5c25522b47b4b29c98dcb9               1 2018-06-08 17:31:20
# 39999  14aa47b7fe5c25522b47b4b29c98dcb9               1 2018-08-08 15:30:17
# 40000  f53103a77d9cf245e579ea37e5ec51f0               1 2018-06-29 14:57:15
# ...                                 ...             ...                 ...
# 52709  9a7c6041fa9592d9d9ef6cfe62a71f8c               1 2018-06-20 18:58:12
# 52710  9a7c6041fa9592d9d9ef6cfe62a71f8c               1 2018-06-28 17:18:27
# 52711  9a7c6041fa9592d9d9ef6cfe62a71f8c               1 2017-08-25 15:50:13
# 52712  9a7c6041fa9592d9d9ef6cfe62a71f8c               1 2018-01-16 21:31:29
# 52713  106392145fca363410d287a815be6de4               1 2018-07-02 08:30:34
#
#       product_category
# 39996   bed_bath_table
# 39997   bed_bath_table
# 39998   bed_bath_table
# 39999   bed_bath_table
# 40000   bed_bath_table
# ...                ...
# 52709   bed_bath_table
# 52710   bed_bath_table
# 52711   bed_bath_table
# 52712   bed_bath_table
# 52713   bed_bath_table
#
# [12718 rows x 4 columns]

# %%
kategori_terlaris_1.dtypes
# Out:
# product_id                     object
# jumlah_terjual                  int64
# shipping_limit_date    datetime64[ns]
# product_category               object
# dtype: object

# %%
# Buat kolom 'month_year' untuk menyimpan bulan dan tahun menggunakan .loc[]

kategori_terlaris_1.loc[:, 'year'] = kategori_terlaris_1['shipping_limit_date'].dt.to_period('Y')
kategori_terlaris_2.loc[:, 'year'] = kategori_terlaris_2['shipping_limit_date'].dt.to_period('Y')
kategori_terlaris_3.loc[:, 'year'] = kategori_terlaris_3['shipping_limit_date'].dt.to_period('Y')
kategori_terlaris_4.loc[:, 'year'] = kategori_terlaris_4['shipping_limit_date'].dt.to_period('Y')
kategori_terlaris_5.loc[:, 'year'] = kategori_terlaris_5['shipping_limit_date'].dt.to_period('Y')
# Out:
# <ipython-input-168-237754453e14>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kategori_terlaris_1.loc[:, 'year'] = kategori_terlaris_1['shipping_limit_date'].dt.to_period('Y')
# <ipython-input-168-237754453e14>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kategori_terlaris_2.loc[:, 'year'] = kategori_terlaris_2['shipping_limit_date'].dt.to_period('Y')
# <ipython-input-168-237754453e14>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kategori_terlaris_3.loc[:, 'year'] = kategori_terlaris_3['shipping_limit_date'].dt.to_period('Y')
# <ipython-input-168-237754453e14>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kategori_terlaris_4.loc[:, 'year'] = kategori_terlaris_4['shipping_limit_date'].dt.to_period('Y')
# <ipython-input-168-237754453e14>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kategori_terlaris_5.loc[:, 'year'] = kategori_terlaris_5['shipping_limit_date'].dt.to_period('Y')

# %%
# trend penjualan top 1 ketegori

sales_kategory1_trend = kategori_terlaris_1.groupby('year')['jumlah_terjual'].count()
sales_kategory1_trend
# Out:
# year
# 2016      10
# 2017    5991
# 2018    6717
# Freq: A-DEC, Name: jumlah_terjual, dtype: int64

# %%
# trend penjualan top 2 kategori

sales_kategory2_trend = kategori_terlaris_2.groupby('year')['jumlah_terjual'].count()
sales_kategory2_trend
# Out:
# year
# 2016      51
# 2017    3590
# 2018    6029
# Freq: A-DEC, Name: jumlah_terjual, dtype: int64

# %%
# trend penjualan top 3 kategori

sales_kategory3_trend = kategori_terlaris_3.groupby('year')['jumlah_terjual'].count()
sales_kategory3_trend
# Out:
# year
# 2016      19
# 2017    4038
# 2018    4584
# Freq: A-DEC, Name: jumlah_terjual, dtype: int64

# %%
# trend penjualan top 4 kategori

sales_kategory4_trend = kategori_terlaris_4.groupby('year')['jumlah_terjual'].count()
sales_kategory4_trend
# Out:
# year
# 2016      69
# 2017    4058
# 2018    4207
# Freq: A-DEC, Name: jumlah_terjual, dtype: int64

# %%
# trend penjualan top 5 kategori

sales_kategory5_trend = kategori_terlaris_5.groupby('year')['jumlah_terjual'].count()
sales_kategory5_trend
# Out:
# year
# 2016      21
# 2017    3042
# 2018    4764
# Freq: A-DEC, Name: jumlah_terjual, dtype: int64

# %% [markdown]
# #### Explore tabel `df_order_items`, `df_orders`

# %%
growth_month = pd.merge(order_items_dataset_df, orders_dataset_df, on= 'order_id', how= 'inner')
growth_month = growth_month.loc[:, ['order_item_id', 'order_purchase_timestamp', 'price']]
growth_month
# Out:
#         order_item_id order_purchase_timestamp   price
# 0                   1      2017-09-13 08:59:02   58.90
# 1                   1      2017-04-26 10:53:06  239.90
# 2                   1      2018-01-14 14:33:31  199.00
# 3                   1      2018-08-08 10:00:35   12.99
# 4                   1      2017-02-04 13:57:51  199.90
# ...               ...                      ...     ...
# 112645              1      2018-04-23 13:57:06  299.99
# 112646              1      2018-07-14 10:26:46  350.00
# 112647              1      2017-10-23 17:07:56   99.90
# 112648              1      2017-08-14 23:02:59   55.99
# 112649              1      2018-06-09 17:00:18   43.00
#
# [112650 rows x 3 columns]

# %%
display(growth_month.sum())
# Out:
# order_item_id                                                          134936
# order_purchase_timestamp    2017-09-13 08:59:022017-04-26 10:53:062018-01-...
# price                                                              13591643.7
# dtype: object

# %%
growth_month.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_item_id             112650 non-null  int64
#  1   order_purchase_timestamp  112650 non-null  object
#  2   price                     112650 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.4+ MB

# %%
display(growth_month.isnull().sum())
# Out:
# order_item_id               0
# order_purchase_timestamp    0
# price                       0
# dtype: int64

# %%
growth_month['order_purchase_timestamp'] = pd.to_datetime(growth_month['order_purchase_timestamp'])
growth_month.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_item_id             112650 non-null  int64
#  1   order_purchase_timestamp  112650 non-null  datetime64[ns]
#  2   price                     112650 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 3.4 MB

# %%
growth_month.sort_values(by='order_purchase_timestamp', inplace=True)
growth_month
# Out:
#         order_item_id order_purchase_timestamp   price
# 20265               1      2016-09-04 21:15:19   39.99
# 20266               2      2016-09-04 21:15:19   32.90
# 101394              1      2016-09-05 00:15:34   59.50
# 84389               1      2016-09-15 12:16:38   44.99
# 84391               3      2016-09-15 12:16:38   44.99
# ...               ...                      ...     ...
# 4925                2      2018-08-29 14:18:23  209.00
# 9829                1      2018-08-29 14:18:28   45.90
# 1722                1      2018-08-29 14:52:00   24.90
# 23530               1      2018-08-29 15:00:37   84.99
# 37073               1      2018-09-03 09:06:57  145.00
#
# [112650 rows x 3 columns]

# %%
growth_month_grouped = growth_month.groupby(growth_month['order_purchase_timestamp'].dt.to_period('M'))
growth_month_result = growth_month_grouped.mean()
growth_month
# Out:
# <ipython-input-135-1a4151ee95a9>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   growth_month_result = growth_month_grouped.mean()
#         order_item_id order_purchase_timestamp   price
# 20265               1      2016-09-04 21:15:19   39.99
# 20266               2      2016-09-04 21:15:19   32.90
# 101394              1      2016-09-05 00:15:34   59.50
# 84389               1      2016-09-15 12:16:38   44.99
# 84391               3      2016-09-15 12:16:38   44.99
# ...               ...                      ...     ...
# 4925                2      2018-08-29 14:18:23  209.00
# 9829                1      2018-08-29 14:18:28   45.90
# 1722                1      2018-08-29 14:52:00   24.90
# 23530               1      2018-08-29 15:00:37   84.99
# 37073               1      2018-09-03 09:06:57  145.00
#
# [112650 rows x 3 columns]

# %%
growth_month['total_price'] = growth_month['price'] * growth_month['order_item_id']
growth_month
# Out:
#         order_item_id order_purchase_timestamp   price  total_price
# 20265               1      2016-09-04 21:15:19   39.99        39.99
# 20266               2      2016-09-04 21:15:19   32.90        65.80
# 101394              1      2016-09-05 00:15:34   59.50        59.50
# 84389               1      2016-09-15 12:16:38   44.99        44.99
# 84391               3      2016-09-15 12:16:38   44.99       134.97
# ...               ...                      ...     ...          ...
# 4925                2      2018-08-29 14:18:23  209.00       418.00
# 9829                1      2018-08-29 14:18:28   45.90        45.90
# 1722                1      2018-08-29 14:52:00   24.90        24.90
# 23530               1      2018-08-29 15:00:37   84.99        84.99
# 37073               1      2018-09-03 09:06:57  145.00       145.00
#
# [112650 rows x 4 columns]

# %%
growth_month_grouped = growth_month.groupby('order_item_id')
growth_month_result = growth_month_grouped['total_price'].sum()
growth_month
# Out:
#         order_item_id order_purchase_timestamp   price  total_price
# 20265               1      2016-09-04 21:15:19   39.99        39.99
# 20266               2      2016-09-04 21:15:19   32.90        65.80
# 101394              1      2016-09-05 00:15:34   59.50        59.50
# 84389               1      2016-09-15 12:16:38   44.99        44.99
# 84391               3      2016-09-15 12:16:38   44.99       134.97
# ...               ...                      ...     ...          ...
# 4925                2      2018-08-29 14:18:23  209.00       418.00
# 9829                1      2018-08-29 14:18:28   45.90        45.90
# 1722                1      2018-08-29 14:52:00   24.90        24.90
# 23530               1      2018-08-29 15:00:37   84.99        84.99
# 37073               1      2018-09-03 09:06:57  145.00       145.00
#
# [112650 rows x 4 columns]

# %%
growth_month['order_purchase_timestamp'] = pd.to_datetime(growth_month['order_purchase_timestamp'])
growth_month.set_index('order_purchase_timestamp', inplace=True)
growth_month_resampled = growth_month.resample('M').agg({'order_item_id': 'sum', 'price': 'sum'}).reset_index()
print(growth_month_resampled)
# Out:
#    order_purchase_timestamp  order_item_id       price
# 0                2016-09-30             10      267.36
# 1                2016-10-31            457    49507.66
# 2                2016-11-30              0        0.00
# 3                2016-12-31              1       10.90
# 4                2017-01-31           1318   120312.87
# 5                2017-02-28           2252   247303.02
# 6                2017-03-31           3515   374344.30
# 7                2017-04-30           3094   359927.23
# 8                2017-05-31           4802   506071.14
# 9                2017-06-30           4094   433038.60
# 10               2017-07-31           5470   498031.48
# 11               2017-08-31           5947   573971.68
# 12               2017-09-30           5742   624401.69
# 13               2017-10-31           6614   664219.43
# 14               2017-11-30          10630  1010271.37
# 15               2017-12-31           7351   743914.17
# 16               2018-01-31           9748   950030.36
# 17               2018-02-28           9405   844178.71
# 18               2018-03-31           9837   983213.44
# 19               2018-04-30           9723   996647.75
# 20               2018-05-31           9599   996517.68
# 21               2018-06-30           8495   865124.31
# 22               2018-07-31           8386   895507.22
# 23               2018-08-31           8445   854686.33
# 24               2018-09-30              1      145.00

# %%
orders_dataset_df = pd.read_csv("/orders_dataset.csv", na_values = missing_value_format)
filter = orders_dataset_df[(orders_dataset_df['order_purchase_timestamp'] >= "2018-01-01") & (orders_dataset_df['order_purchase_timestamp'] < "2019-01-01") ]
filter2 = filter[[('order_purchase_timestamp')]]

jumlah = len(filter.axes[0])
jumlah2 = len(filter2.axes[0])
print("")
print("Transaksi Dalam 1 Tahun Terakhir")
display(filter2)
# Out:
# Transaksi Dalam 1 Tahun Terakhir
#       order_purchase_timestamp
# 1          2018-07-24 20:41:37
# 2          2018-08-08 08:38:49
# 4          2018-02-13 21:18:39
# 12         2018-06-07 10:06:19
# 13         2018-07-25 17:44:10
# ...                        ...
# 99428      2018-06-22 20:53:29
# 99430      2018-03-04 22:48:38
# 99437      2018-02-06 12:58:58
# 99439      2018-01-08 21:28:27
# 99440      2018-03-08 20:57:30
#
# [54011 rows x 1 columns]

# %% [markdown]
# #### Explore tabel `df_orders`

# %%
orders_dataset_df = pd.read_csv("/orders_dataset.csv", na_values = missing_value_format)

# %%
filter = orders_dataset_df[(orders_dataset_df['order_status'] == "delivered") & (orders_dataset_df['order_delivered_customer_date'] > "2017-12-31") & (orders_dataset_df['order_delivered_customer_date'] < "2018-12-01")]
filter2 = filter[[('order_delivered_customer_date'),('order_estimated_delivery_date')]]
filter3 = filter2[(filter2['order_delivered_customer_date'] > filter2['order_estimated_delivery_date'])]
filter4 = filter2[(filter2['order_delivered_customer_date'] < filter2['order_estimated_delivery_date'])]

# %%
jumlah = len(filter3.axes[0])
jumlah2 = len(filter4.axes[0])

# %%
print("")
print("Data Pengiriman Tepat Waktu")
print(filter4)
# Out:
# Data Pengiriman Tepat Waktu
#       order_delivered_customer_date order_estimated_delivery_date
# 1               2018-08-07 15:27:45           2018-08-13 00:00:00
# 2               2018-08-17 18:06:29           2018-09-04 00:00:00
# 4               2018-02-16 18:17:02           2018-02-26 00:00:00
# 12              2018-06-19 12:05:52           2018-07-18 00:00:00
# 13              2018-07-30 15:52:25           2018-08-08 00:00:00
# ...                             ...                           ...
# 99428           2018-07-03 19:48:54           2018-07-23 00:00:00
# 99430           2018-03-13 18:54:32           2018-03-26 00:00:00
# 99437           2018-02-28 17:37:56           2018-03-02 00:00:00
# 99439           2018-01-25 23:32:54           2018-02-15 00:00:00
# 99440           2018-03-16 13:08:30           2018-04-03 00:00:00
#
# [49603 rows x 2 columns]

# %%
print("")
print("Data Pengiriman Telat")
print(filter3)
# Out:
# Data Pengiriman Telat
#       order_delivered_customer_date order_estimated_delivery_date
# 25              2018-03-21 22:03:54           2018-03-12 00:00:00
# 35              2018-03-20 00:59:25           2018-03-20 00:00:00
# 57              2018-04-03 13:28:46           2018-04-02 00:00:00
# 102             2018-08-03 19:28:47           2018-08-02 00:00:00
# 110             2018-01-23 21:38:52           2017-12-22 00:00:00
# ...                             ...                           ...
# 99328           2018-04-26 12:54:39           2018-04-25 00:00:00
# 99396           2018-08-21 00:03:26           2018-08-16 00:00:00
# 99397           2018-04-05 19:59:49           2018-04-02 00:00:00
# 99425           2018-04-11 00:48:31           2018-04-09 00:00:00
# 99432           2018-01-26 15:45:14           2018-01-18 00:00:00
#
# [5675 rows x 2 columns]

# %% [markdown]
# #### Explore tabel `df_order_items`

# %%
order_items_dataset_df.sample(5)
# Out:
#                                 order_id  order_item_id  \
# 106026  f0f1e72d7f4186b7a9e271487091c9ab              1
# 48743   6ec56173121c5972d0fd631f0f084d93              1
# 109771  f97b2bdfbaca9c2f04722d8cbc8cc8a5              1
# 11195   1974ffc6d3d8f6e9d8f82fcffa4be2a5              1
# 12721   1cd29ff24c716ad3002179320343005a              1
#
#                               product_id                         seller_id  \
# 106026  708695ee28aeef6c879a6c9d5f5269de  3d871de0142ce09b7081e2b9d1733cb1
# 48743   4fe644d766c7566dbc46fb851363cb3b  c31eff8334d6b3047ed34bebd4d62c36
# 109771  054515fd15bc1a2029f10de97ffa9120  e9779976487b77c6d4ac45f75ec7afe9
# 11195   e0cf79767c5b016251fe139915c59a26  da8622b14eb17ae2831f4ac5b9dab84a
# 12721   629e019a6f298a83aeecc7877964f935  c003204e1ab016dfa150abc119207b24
#
#        shipping_limit_date   price  freight_value
# 106026 2018-01-05 13:17:17   79.00          12.05
# 48743  2018-07-24 10:35:15   99.99          23.50
# 109771 2018-08-13 18:45:20   43.00          18.40
# 11195  2018-07-23 14:25:20   29.90           7.47
# 12721  2018-04-12 02:50:25  109.90          34.31

# %%
order_items_dataset_df.describe(include = 'all')
# Out:
# <ipython-input-148-f8a0a3efe7c4>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   order_items_dataset_df.describe(include = 'all')
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# first                                NaN            NaN
# last                                 NaN            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# top     aca2eb7d00ea1a7b8ebd4e68314663af  6560211a19b47992c3666cc44a7e94c0
# freq                                 527                              2033
# first                                NaN                               NaN
# last                                 NaN                               NaN
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         shipping_limit_date          price  freight_value
# count                112650  112650.000000  112650.000000
# unique                93318            NaN            NaN
# top     2017-07-21 18:25:23            NaN            NaN
# freq                     21            NaN            NaN
# first   2016-09-19 00:15:34            NaN            NaN
# last    2020-04-09 22:35:08            NaN            NaN
# mean                    NaN     120.653739      19.990320
# std                     NaN     183.633928      15.806405
# min                     NaN       0.850000       0.000000
# 25%                     NaN      39.900000      13.080000
# 50%                     NaN      74.990000      16.260000
# 75%                     NaN     134.900000      21.150000
# max                     NaN    6735.000000     409.680000

# %%
order_items_dataset_df.groupby('order_item_id').agg({
    'order_id' : 'nunique',
    'seller_id' : 'nunique'
})
# Out:
#                order_id  seller_id
# order_item_id
# 1                 98666       3088
# 2                  9803       1531
# 3                  2287        730
# 4                   965        431
# 5                   460        262
# 6                   256        163
# 7                    58         43
# 8                    36         25
# 9                    28         19
# 10                   25         18
# 11                   17         13
# 12                   13          9
# 13                    8          7
# 14                    7          7
# 15                    5          5
# 16                    3          3
# 17                    3          3
# 18                    3          3
# 19                    3          3
# 20                    3          3
# 21                    1          1

# %% [markdown]
# #### Explore tabel `df_order_reviews`

# %%
order_reviews_dataset_df.describe(include = 'all')

# %%
order_reviews_dataset_df.groupby('review_score').agg({
    'order_id' : 'count'
})

# %% [markdown]
# #### Explore tabel `df_sellers_`

# %%
sellers_dataset_df.sample(8)
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 2844  e8f6dc8e6a1dcde89d20e3995c8d90b3                    3476
# 2157  e601b04acf48b4576e73ddca9481f0dc                    4476
# 747   6c7d50c24b3ccd2fd83b44d8bb34e073                   19025
# 663   20a8b0dc55da94fe74d112082427c84f                   13312
# 1089  b0f2a6122a90a93eb03e68653dd960e3                   80710
# 2123  f543ba3c973276f519d89d59bd46cead                   15030
# 201   8132b9bd16876e1b0f8808d43825dd48                   88058
# 1709  173d56ffbd4c56cb80fc3615487d712b                   11370
#
#                 seller_city seller_state
# 2844              sao paulo           SP
# 2157              sao paulo           SP
# 747     presidente prudente           SP
# 663                     itu           SP
# 1089               curitiba           PR
# 2123  sao jose do rio preto           SP
# 201           florianopolis           SC
# 1709            sao vicente           SP

# %%
sellers_dataset_df.describe(include = 'all')
# Out:
#                                seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         610
# top     ceb7b4fb9401cd378de7886317ad1b47                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# std                                  NaN            32713.453830         NaN
# min                                  NaN             1001.000000         NaN
# 25%                                  NaN             7093.500000         NaN
# 50%                                  NaN            14940.000000         NaN
# 75%                                  NaN            64552.500000         NaN
# max                                  NaN            99730.000000         NaN
#
#        seller_state
# count          3095
# unique           23
# top              SP
# freq           1849
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %%
sellers_dataset_df.groupby('seller_state').agg({
    'seller_id' : 'count'
})
# Out:
#               seller_id
# seller_state
# AC                    1
# AM                    1
# BA                   19
# CE                   13
# DF                   30
# ES                   23
# GO                   40
# MA                    1
# MG                  244
# MS                    5
# MT                    4
# PA                    1
# PB                    6
# PE                    9
# PI                    1
# PR                  349
# RJ                  171
# RN                    5
# RO                    2
# RS                  129
# SC                  190
# SE                    2
# SP                 1849

# %% [markdown]
# #### Explore tabel `df_order_items` & `df_order_reviews`

# %%
orders_df = pd.merge(
    left=order_items_dataset_df,
    right=order_reviews_dataset_df,
    left_on = 'order_id',
    right_on= 'order_id'
)
orders_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  \
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# 4 2017-02-13 13:57:51  199.90          18.14
#
#                           review_id  review_score review_comment_title  \
# 0  97ca439bc427b48bc1cd7177abe71365             5          No Comments
# 1  7b07bacd811c4117b742569b04ce3580             4          No Comments
# 2  0c5b33dea94867d1ac402749e5438e8b             5          No Comments
# 3  f4028d019cb58564807486a6aaf33817             4          No Comments
# 4  940144190dcba6351888cafa43f3a3a5             5          No Comments
#
#                               review_comment_message review_creation_date  \
# 0     Perfeito, produto entregue antes do combinado.           2017-09-21
# 1                                        No Comments           2017-05-13
# 2  Chegou antes do prazo previsto e o produto sur...           2018-01-23
# 3                                        No Comments           2018-08-15
# 4            Gostei pois veio no prazo determinado .           2017-03-02
#
#   review_answer_timestamp
# 0     2017-09-22 10:57:03
# 1     2017-05-15 11:34:13
# 2     2018-01-23 16:06:31
# 3     2018-08-15 16:39:01
# 4     2017-03-03 10:54:59

# %%
orders_df.groupby(['order_id','seller_id']).review_id.count().sort_values(ascending = False)
# Out:
# order_id                          seller_id
# 8272b63d03f5f79c56e9e4120aec44ef  2709af9587499e95e803a6498a5a56e9    21
# 1b15974a0141d54e36626dca3fdc731a  8e6d7754bc7e0f22c96d255ebda59eba    20
# 5a3b1c29a49756e75f1ef513383c0c12  d2374cbcbb3ca4ab1086534108cc3ab7    18
# 9ef13efd6949e4573a18964dd1bbe7f5  0b36063d5818f81ccb94b54adfaebbf5    15
# 428a2f660dc84138d969ccd69a0ab6d5  f326006815956455b2859abd58fe7e39    15
#                                                                       ..
# 59c153fdba2562afd8554a380231559e  cd06602b43d8800bd0afad514919d35c     1
# 59c134c32edc0046c31ad8bd6f521b61  dbb9b48c841a0e39e21f98e1a6b2ec3e     1
# 59c0d4b067270f98e28b82c5ce59db9c  17ca9b9e9b9ef8fdb529001b49ebb50f     1
# 59be4c2310298e01725dd55622c4f038  dd2bdf855a9172734fbc3744021ae9b9     1
# fffe41c64501cc87c801fd61db3f6244  f7ccf836d21b2fb1de37564105216cc1     1
# Name: review_id, Length: 99247, dtype: int64

# %%
orders_df.isna().sum()
# Out:
# order_id                   0
# order_item_id              0
# product_id                 0
# seller_id                  0
# shipping_limit_date        0
# price                      0
# freight_value              0
# review_id                  0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %% [markdown]
# #### Explore tabel `orders_df` & `df_sellers`

# %%
orders_sellers_df = pd.merge(
    left=orders_df,
    right=sellers_dataset_df,
    left_on="seller_id",
    right_on="seller_id"
)
orders_sellers_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  0188777fe321843a18be24a6e9aa1e53              1
# 2  0191bbb5166d4b9a68df11797d5acfa9              1
# 3  03054d8a8eefc2981cfad06f58e27979              1
# 4  0c325ea6925de749e1420be0cf43587c              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  436c8d57ff8d4aa254318e9bd9b48c83  48436dade18ac8b2bce089ec2a041202
# 2  ec02a5d380128f7a188e9ce8f3ddd832  48436dade18ac8b2bce089ec2a041202
# 3  3e31fd1419cc4cd6adad1925e72e3a03  48436dade18ac8b2bce089ec2a041202
# 4  3a135477bf41350a0b1d8afdf616d446  48436dade18ac8b2bce089ec2a041202
#
#   shipping_limit_date  price  freight_value                         review_id  \
# 0 2017-09-19 09:45:35   58.9          13.29  97ca439bc427b48bc1cd7177abe71365
# 1 2017-07-31 14:35:11   55.9           9.94  1fac9acb29e014e3b9b393d5c8505f99
# 2 2017-08-16 12:30:15  132.9          20.17  2eab04a8f45efa131d44cf58b37ab595
# 3 2017-10-09 10:35:11   58.9          15.16  9d0e152a1983460f059ddffcb8af03bb
# 4 2017-07-06 15:43:50  139.9          16.74  f4fad24d4bb3462bab004be9a0b753f0
#
#    review_score review_comment_title  \
# 0             5          No Comments
# 1             5          No Comments
# 2             5          No Comments
# 3             5          No Comments
# 4             4          No Comments
#
#                               review_comment_message review_creation_date  \
# 0     Perfeito, produto entregue antes do combinado.           2017-09-21
# 1                                              ÓTIMO           2017-07-29
# 2  Recebi o patines em perfeitas condições bem an...           2017-08-25
# 3                                        No Comments           2017-10-20
# 4  Atendimento excelente,o produto chegou antes d...           2017-07-11
#
#   review_answer_timestamp  seller_zip_code_prefix    seller_city seller_state
# 0     2017-09-22 10:57:03                   27277  volta redonda           SP
# 1     2017-08-01 20:55:50                   27277  volta redonda           SP
# 2     2017-08-28 12:57:25                   27277  volta redonda           SP
# 3     2017-10-20 23:45:27                   27277  volta redonda           SP
# 4     2017-07-13 23:18:14                   27277  volta redonda           SP

# %%
orders_sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112372 entries, 0 to 112371
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   order_id                 112372 non-null  object
#  1   order_item_id            112372 non-null  int64
#  2   product_id               112372 non-null  object
#  3   seller_id                112372 non-null  object
#  4   shipping_limit_date      112372 non-null  datetime64[ns]
#  5   price                    112372 non-null  float64
#  6   freight_value            112372 non-null  float64
#  7   review_id                112372 non-null  object
#  8   review_score             112372 non-null  int64
#  9   review_comment_title     112372 non-null  object
#  10  review_comment_message   112372 non-null  object
#  11  review_creation_date     112372 non-null  datetime64[ns]
#  12  review_answer_timestamp  112372 non-null  datetime64[ns]
#  13  seller_zip_code_prefix   112372 non-null  int64
#  14  seller_city              112372 non-null  object
#  15  seller_state             112372 non-null  object
# dtypes: datetime64[ns](3), float64(2), int64(3), object(8)
# memory usage: 14.6+ MB

# %%
orders_sellers_df.sort_values(by = 'review_score', ascending =False)
# Out:
#                                order_id  order_item_id  \
# 0      00010242fe8c5a6d1ba2dd792cb16214              1
# 65201  ab9a3c29c4b67aaca311cad95058153a              1
# 65212  b4089e5d326faccf865d5ab5463a22ce              1
# 65209  b23dfa1c97d08f8d2017e85dbdc5b1aa              1
# 65208  b07bd6d2317297a22b80a9836b464d59              1
# ...                                 ...            ...
# 76618  35a3d210c364e3747478f468b0547bb2              1
# 10868  3d76cc1cc5ebdd45a03c0b51f79d43b1              2
# 60271  f0b3b8301161711933b5fa04d6191a0e              1
# 20808  f3468d6a2c7586711e9952242898aad4              3
# 32536  c5536b9cf89dc947c7c0d0287528cda8              1
#
#                              product_id                         seller_id  \
# 0      4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 65201  f71973c922ccaab05514a36a8bc741b8  5dceca129747e92ff8ef7a997dc4f8ca
# 65212  0efb0a47500c44e05a5930cae12307d4  5dceca129747e92ff8ef7a997dc4f8ca
# 65209  6f790ed0f75949b7fa234ec087aed912  5dceca129747e92ff8ef7a997dc4f8ca
# 65208  811c8bc1ddef7440e27dfb8cb536f334  5dceca129747e92ff8ef7a997dc4f8ca
# ...                                 ...                               ...
# 76618  52a646aa308987e28c375b41081de428  430315b7bb4b6e4b3c978f9dfa9b0558
# 10868  6fd82d8f842424334fedf31190e54d24  6560211a19b47992c3666cc44a7e94c0
# 60271  0a4093a4af429dc0a9334300e5c13ae5  da8622b14eb17ae2831f4ac5b9dab84a
# 20808  31a89a7044c5b133cf646404a4e86022  955fee9216a65b617aa5c0531780ce60
# 32536  ed38e11473775cde0d65f698aa0a4d27  3d871de0142ce09b7081e2b9d1733cb1
#
#       shipping_limit_date  price  freight_value  \
# 0     2017-09-19 09:45:35   58.9          13.29
# 65201 2017-05-17 14:10:18  109.9          21.42
# 65212 2018-02-01 18:30:25  299.9          53.29
# 65209 2017-02-01 17:05:18  669.0          41.00
# 65208 2018-06-29 11:32:43  428.0          46.99
# ...                   ...    ...            ...
# 76618 2018-05-02 18:10:04   29.0          18.23
# 10868 2017-03-14 04:03:29   45.0          14.57
# 60271 2018-03-15 16:48:15   29.9          18.23
# 20808 2018-05-17 20:56:02  150.0          17.64
# 32536 2017-12-14 11:12:58   99.0          17.94
#
#                               review_id  review_score  \
# 0      97ca439bc427b48bc1cd7177abe71365             5
# 65201  f230b63fac0181e0aa39a44f6a90791c             5
# 65212  f79e1ee49a80d9d132e33d0b3a498111             5
# 65209  a550516cf299801f549ba3d8a0c0aa07             5
# 65208  f061444920c42b63a1a97141431973e4             5
# ...                                 ...           ...
# 76618  c74e7e7e7df2d5b606f54836042b3e13             1
# 10868  6b0fd9d7bea27ff9740eca8c6b94b179             1
# 60271  af629ffeb2901420c78591a1504d89a8             1
# 20808  c40a6b6e0181e5ec0d12cbc2e12c49d3             1
# 32536  5d2e4b2e1347683843d8da6af8ef4c6f             1
#
#             review_comment_title  \
# 0                    No Comments
# 65201                No Comments
# 65212                No Comments
# 65209                No Comments
# 65208                No Comments
# ...                          ...
# 76618                tranca moto
# 10868                No Comments
# 60271                No Comments
# 20808  falta de produto e quebra
# 32536                No Comments
#
#                                   review_comment_message review_creation_date  \
# 0         Perfeito, produto entregue antes do combinado.           2017-09-21
# 65201  Comprei este produto adorei os benefícios que ...           2017-05-16
# 65212  RECEBI ANTES DO PRAZO, O PRODUTO É EXATAMENTE ...           2018-01-26
# 65209                                        No Comments           2017-02-18
# 65208                                        No Comments           2018-07-05
# ...                                                  ...                  ...
# 76618                                      produto fraco           2018-05-08
# 10868  Não recebi o produto Relógio Feminino de Pulso...           2017-03-11
# 60271                                        No Comments           2018-04-04
# 20808   Faltou 1 produto e os que recebi 1 veio quebrado           2018-05-23
# 32536  Comprei duas bolsas mais só recebi 1.... tive ...           2017-12-30
#
#       review_answer_timestamp  seller_zip_code_prefix            seller_city  \
# 0         2017-09-22 10:57:03                   27277          volta redonda
# 65201     2017-05-18 22:50:30                   13450  santa barbara d´oeste
# 65212     2018-01-27 19:04:34                   13450  santa barbara d´oeste
# 65209     2017-02-18 13:27:27                   13450  santa barbara d´oeste
# 65208     2018-07-07 11:55:34                   13450  santa barbara d´oeste
# ...                       ...                     ...                    ...
# 76618     2018-05-11 10:20:29                    4857              sao paulo
# 10868     2017-03-12 13:57:04                    5849              sao paulo
# 60271     2018-04-04 16:17:01                   13405             piracicaba
# 20808     2018-05-23 22:23:00                    4782              sao paulo
# 32536     2017-12-31 16:30:47                   13232   campo limpo paulista
#
#       seller_state
# 0               SP
# 65201           SP
# 65212           SP
# 65209           SP
# 65208           SP
# ...            ...
# 76618           SP
# 10868           SP
# 60271           SP
# 20808           SP
# 32536           SP
#
# [112372 rows x 16 columns]

# %%
orders_sellers_df.isna().sum()
# Out:
# order_id                   0
# order_item_id              0
# product_id                 0
# seller_id                  0
# shipping_limit_date        0
# price                      0
# freight_value              0
# review_id                  0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# seller_zip_code_prefix     0
# seller_city                0
# seller_state               0
# dtype: int64

# %%
counter = pd.DataFrame(orders_sellers_df.groupby('seller_city').agg({
    'review_score' : 'sum',
    'review_id' : 'count',
    'order_id'  : 'count'
}).sort_values('review_score',ascending=False))
counter
# Out:
#                 review_score  review_id  order_id
# seller_city
# sao paulo             111989      27862     27862
# ibitinga               29567       7781      7781
# curitiba               12820       3025      3025
# santo andre            12284       3003      3003
# belo horizonte         10774       2578      2578
# ...                      ...        ...       ...
# carmo da mata              1          1         1
# pirassununga               1          1         1
# rio branco                 1          1         1
# eusebio                    1          1         1
# divisa nova                1          1         1
#
# [610 rows x 3 columns]

# %%
rating_counter = pd.DataFrame(orders_sellers_df.groupby('seller_city').review_score.sum().sort_values(ascending=False))
valid_rating_counter = rating_counter.drop(index=[row for row in rating_counter.index if 5000 > rating_counter.loc[row, 'review_score']])
valid_rating_counter
# Out:
#                        review_score
# seller_city
# sao paulo                    111989
# ibitinga                      29567
# curitiba                      12820
# santo andre                   12284
# belo horizonte                10774
# sao jose do rio preto         10251
# rio de janeiro                 9810
# guarulhos                      9641
# maringa                        8819
# ribeirao preto                 8723
# piracicaba                     7748
# campinas                       5633
# praia grande                   5617
# itaquaquecetuba                5612
# salto                          5513

# %%
review_counter = pd.DataFrame(orders_sellers_df.groupby('seller_city').review_id.count().sort_values(ascending=False))
valid_review_counter = review_counter.drop(index=[row for row in review_counter.index if 1200 > review_counter.loc[row, 'review_id']])
valid_review_counter
# Out:
#                        review_id
# seller_city
# sao paulo                  27862
# ibitinga                    7781
# curitiba                    3025
# santo andre                 3003
# belo horizonte              2578
# sao jose do rio preto       2570
# rio de janeiro              2431
# guarulhos                   2365
# ribeirao preto              2263
# maringa                     2241
# piracicaba                  1920
# itaquaquecetuba             1652
# campinas                    1422
# praia grande                1355
# salto                       1333

# %%
ratio = valid_rating_counter / valid_review_counter.values
overall = pd.DataFrame(ratio.drop(index=[row for row in ratio.index if 4 > ratio.loc[row, 'review_score']]))
overall
# Out:
#                  review_score
# seller_city
# sao paulo            4.019417
# curitiba             4.238017
# santo andre          4.090576
# belo horizonte       4.179209
# rio de janeiro       4.035376
# guarulhos            4.076533
# piracicaba           4.035417
# itaquaquecetuba      4.141697
# salto                4.135784

# %%
worstCity = pd.DataFrame(counter.drop(index=[row for row in counter.index if 1 < counter.loc[row, 'review_score'] and counter.loc[row, 'review_id'] and counter.loc[row, 'order_id']]))
worstCity
# Out:
#                   review_score  review_id  order_id
# seller_city
# aguas claras df              1          1         1
# medianeira                   1          1         1
# marapoama                    1          1         1
# macatuba                     1          1         1
# cordilheira alta             1          1         1
# orleans                      1          1         1
# ipua                         1          1         1
# carmo da mata                1          1         1
# pirassununga                 1          1         1
# rio branco                   1          1         1
# eusebio                      1          1         1
# divisa nova                  1          1         1

# %% [markdown]
# #### Explore tabel `df_customers`

# %%
customers_dataset_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# count               99441.000000         99441          99441
# unique                       NaN          4119             27
# top                          NaN     sao paulo             SP
# freq                         NaN         15540          41746
# mean                35137.474583           NaN            NaN
# std                 29797.938996           NaN            NaN
# min                  1003.000000           NaN            NaN
# 25%                 11347.000000           NaN            NaN
# 50%                 24416.000000           NaN            NaN
# 75%                 58900.000000           NaN            NaN
# max                 99990.000000           NaN            NaN

# %%
customers_dataset_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 31092  c7c0ba6613929d7d0a82ef70a992a184  0c9f948ba785676170057686aa1521f5
# 36355  32960cfa578ed22c98c6c039e9c29861  b03b3e60f7e9dedc0d57b3e8c8d26e60
# 32321  b638614e44a5882a50381d68c597ea96  85a8d4dbd48bdbfea91d61cbc16daad1
# 73443  74d841cb5ec776ad34ebc824ad9906ce  de0fcbf13e92c68080d909e87da3b510
# 49330  4c3351d2b41593f41ee70e5cf0e13518  57f28663f0420b0a39c14f24750b3db4
#
#        customer_zip_code_prefix customer_city customer_state
# 31092                     14140     cravinhos             SP
# 36355                      1422     sao paulo             SP
# 32321                     13186   hortolandia             SP
# 73443                      4517     sao paulo             SP
# 49330                     13327         salto             SP

# %%
customers_dataset_df.customer_id.is_unique
# Out:
# True

# %%
customers_dataset_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
df_data_customer = pd.read_csv('/customers_dataset.csv')
df_data_customer.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
count = df_data_customer['customer_city'].value_counts()
count
# Out:
# sao paulo            15540
# rio de janeiro        6882
# belo horizonte        2773
# brasilia              2131
# curitiba              1521
#                      ...
# bequimao                 1
# andarai                  1
# vargem grande            1
# curvelandia              1
# eugenio de castro        1
# Name: customer_city, Length: 4119, dtype: int64

# %%
top5 = count.head(5)
top = pd.DataFrame(top5)
top = top5.astype(int)
top
# Out:
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
# Name: customer_city, dtype: int64
